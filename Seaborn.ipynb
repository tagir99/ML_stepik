# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
# получать результаты визуализаций в юпитер-ноутбуке
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_performance = pd.read_csv('C:/Users/TAGIR/StudentsPerformance.csv')
students_performance.columns = [x.replace(" ", "_") for x in students_performance.columns]
students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.math_score.hist()
# Out:
# <AxesSubplot:>

# %%
students_performance.plot.scatter(x = "math_score", y = "reading_score")
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='reading_score'>

# %%
sns.lmplot(x = "math_score", y = "reading_score", hue = "lunch", data = students_performance)

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
sns.lineplot(x = df.index, y = df.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
plt.plot(df.index, df.income)

# %%
dff = pd.read_csv('C:/Users/TAGIR/dataset_209770_6 (2).txt', sep = " ")

# %%
dff.plot.scatter(x = "x", y = "y")
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
# решение со stepik
df = pd.read_csv('path_to_dataset', sep=' ', header=None)
sns.scatterplot(df.iloc[:, 0], df.iloc[:, 1])

# %%
df = pd.read_csv('C:/Users/TAGIR/dota_hero_stats.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
lenths = [len(r.split(',')) for r in df.roles]
df['lenths'] = lenths

# %%
# какое число ролей у большинства героев
lenths
rl = [i for i in lenths if i == 4]
len(rl)
# Out:
# 38

# %%
iris = pd.read_csv('C:/Users/TAGIR/ML Stepik Course/iris.csv')

# %%
iris.head()
# Out:
#    Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0           0           5.1          3.5           1.4          0.2        0
# 1           1           4.9          3.0           1.4          0.2        0
# 2           2           4.7          3.2           1.3          0.2        0
# 3           3           4.6          3.1           1.5          0.2        0
# 4           4           5.0          3.6           1.4          0.2        0

# %%
sns.violinplot(iris['petal length'], orient='v');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
sns.pairplot(iris)
